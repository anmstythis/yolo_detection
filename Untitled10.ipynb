# %%
from ultralytics import YOLO

model = YOLO('yolov8m-seg.pt')
train = model.train(data='YOLO_dataset/data.yaml', epochs=350, imgsz=640, patience=200, batch=8)
# Out:
# ...
# 100%|██████████| 52.4M/52.4M [00:50<00:00, 1.08MB/s]
# New https://pypi.org/project/ultralytics/8.3.152 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.139  Python-3.11.5 torch-2.7.0+cu126 CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# ...
